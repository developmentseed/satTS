# %%
from satTS.cropclass import tsmask
from satTS.cropclass import tsclust
from os import listdir
import re
import matplotlib.pyplot as plt
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-51d9907990f5> in <module>()
# ----> 1 from satTS.cropclass import tsmask
#       2 from satTS.cropclass import tsclust
#       3 from os import listdir
#       4 import re
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'satTS'
